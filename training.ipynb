# %% [markdown]
# ## PreTrain on 2015 data

# %%
# !catalyst-dl run --config configs/efficientnet-4/pretraining.yml --verbose --seed 42
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0906 11:08:00.986664 140022964381504 deprecation_wrapper.py:119] From /root/anaconda2/envs/nikita_tensorflow/lib/python3.7/site-packages/catalyst/utils/seed.py:26: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Loaded pretrained weights for efficientnet-b4
# Learnable parameters:  17550409
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# ...

# %% [markdown]
# ## Train on 80% data

# %%
# !catalyst-dl run --config configs/efficientnet-4/finetuning.yml --verbose --seed 42
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0907 11:35:03.557054 140620185089856 deprecation_wrapper.py:119] From /root/anaconda2/envs/nikita_tensorflow/lib/python3.7/site-packages/catalyst/utils/seed.py:26: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Loaded pretrained weights for efficientnet-b4
# Learnable parameters:  1793
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# ...

# %% [markdown]
# ## Train on 100% data

# %%
# !catalyst-dl run --config configs/efficientnet-4/finetuning.yml --verbose --seed 42
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0907 13:23:30.803514 139690519816000 deprecation_wrapper.py:119] From /root/anaconda2/envs/nikita_tensorflow/lib/python3.7/site-packages/catalyst/utils/seed.py:26: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# Loaded pretrained weights for efficientnet-b4
# Learnable parameters:  1793
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# ...
